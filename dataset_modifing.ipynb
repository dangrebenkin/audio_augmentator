# %%
from datasets import DatasetDict
from audio_augmentator.utils import get_speech_timestamps, collect_chunks, tensor_normalization, signal_energy_noise_search
import torch
import numpy as np
import soundfile as sf
import os

# %%
sf.__libsndfile_version__
# Out:
# '1.2.0'

# %%
noises_dataset_path = 'noises_dataset'
noises_dataset = DatasetDict.load_from_disk(noises_dataset_path)

# %%
# %%timeit
noises_dataset
# Out:
# DatasetDict({
#     household_noises: Dataset({
#         features: ['audio'],
#         num_rows: 1676
#     })
#     speech_noises: Dataset({
#         features: ['audio'],
#         num_rows: 4049
#     })
#     background_music_noises: Dataset({
#         features: ['audio'],
#         num_rows: 1972
#     })
#     pets_noises: Dataset({
#         features: ['audio'],
#         num_rows: 862
#     })
# })

# %%
# %%timeit
house = noises_dataset['household_noises']

# %%
# %%timeit
speech = noises_dataset['speech_noises']

# %%
# %%timeit 's'
speech[1000]
# Out:
# {'audio': {'path': 'ru_0018.wav',
#   'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          -3.05175781e-05,  0.00000000e+00,  0.00000000e+00]),
#   'sampling_rate': 16000}}

# %%
silero_vad_model_path = "silero_vad.jit"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = torch.jit.load(silero_vad_model_path,
                       map_location=device)
model = model.to(device)

# %%
# speech[]

# %%
def preprocess_speech(
        speech_array: np.ndarray,
        vad_model
) -> torch.tensor:
    noise_to_mix_tensor = torch.from_numpy(np.float32(speech_array))
    noise_to_mix_tensor = tensor_normalization(noise_to_mix_tensor)

    speech_timestamps = get_speech_timestamps(
        input_audio=noise_to_mix_tensor,
        silero_vad_model=vad_model
    )
    if len(speech_timestamps) >= 1:
        noise_to_mix_tensor = collect_chunks(
            speech_timestamps,
            noise_to_mix_tensor
        )
    noise_to_mix_tensor = torch.unsqueeze(noise_to_mix_tensor, 0)
    return noise_to_mix_tensor

def preprocess_other(
        audio_array: np.ndarray
):
    noise_to_mix_array = signal_energy_noise_search(audio_array)
    noise_to_mix_array = np.float32(noise_to_mix_array)
    noise_to_mix_tensor = torch.unsqueeze(torch.from_numpy(noise_to_mix_array), 0)
    return noise_to_mix_tensor

def speech_mapper(example):
    example['audio']['array'] = preprocess_speech(example['audio']['array'], vad_model=model)
    return example

# %%
speech.map(speech_mapper, num_proc=4)
# speech_mapper(speech[1001])
# speech.map
# Out:
# Map (num_proc=4):   0%|          | 0/4049 [00:00<?, ? examples/s]
# Process ForkPoolWorker-35:
# Traceback (most recent call last):
#   File "/home/limp/miniconda3/envs/smarthome/lib/python3.9/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-36:
#   File "/home/limp/miniconda3/envs/smarthome/lib/python3.9/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/smarthome/lib/python3.9/site-packages/datasets/utils/py_utils.py:640, in iflatmap_unordered(pool, func, kwargs_iterable)
#     639 try:
# --> 640     yield queue.get(timeout=0.05)
#     641 except Empty:
#
# File <string>:2, in get(self, *args, **kwds)
#
# File ~/miniconda3/envs/smarthome/lib/python3.9/site-packages/multiprocess/managers.py:810, in BaseProxy._callmethod(self, methodname, args, kwds)
#     809 conn.send((self._id, methodname, args, kwds))
# --> 810 kind, result = conn.recv()
#     812 if kind == '#RETURN':
#
# File ~/miniconda3/envs/smarthome/lib/python3.9/site-packages/multiprocess/connection.py:253, in _ConnectionBase.recv(self)
#     252 self._check_readable()
# --> 253 buf = self._recv_bytes()
#     254 return _ForkingPickler.loads(buf.getbuffer())
#
# File ~/miniconda3/envs/smarthome/lib/python3.9/site-packages/multiprocess/connection.py:417, in Connection._recv_bytes(self, maxsize)
#     416 def _recv_bytes(self, maxsize=None):
# --> 417     buf = self._recv(4)
#     418     size, = struct.unpack("!i", buf.getvalue())
#
# File ~/miniconda3/envs/smarthome/lib/python3.9/site-packages/multiprocess/connection.py:382, in Connection._recv(self, size, read)
#     381 while remaining > 0:
# --> 382     chunk = read(handle, remaining)
#     383     n = len(chunk)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 speech.map(speech_mapper, num_proc=4)
#       2 # speech_mapper(speech[1001])
#       3 # speech.map
#
# File ~/miniconda3/envs/smarthome/lib/python3.9/site-packages/datasets/arrow_dataset.py:592, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     590     self: "Dataset" = kwargs.pop("self")
#     591 # apply actual function
# --> 592 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     593 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     594 for dataset in datasets:
#     595     # Remove task templates if a column mapping of the template is no longer valid
#
# File ~/miniconda3/envs/smarthome/lib/python3.9/site-packages/datasets/arrow_dataset.py:557, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     550 self_format = {
#     551     "type": self._format_type,
#     552     "format_kwargs": self._format_kwargs,
#     553     "columns": self._format_columns,
#     554     "output_all_columns": self._output_all_columns,
#     555 }
#     556 # apply actual function
# --> 557 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     558 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     559 # re-apply format to the output
#
# File ~/miniconda3/envs/smarthome/lib/python3.9/site-packages/datasets/arrow_dataset.py:3185, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3179 logger.info(f"Spawning {num_proc} processes")
#    3180 with hf_tqdm(
#    3181     unit=" examples",
#    3182     total=pbar_total,
#    3183     desc=(desc or "Map") + f" (num_proc={num_proc})",
#    3184 ) as pbar:
# -> 3185     for rank, done, content in iflatmap_unordered(
#    3186         pool, Dataset._map_single, kwargs_iterable=kwargs_per_job
#    3187     ):
#    3188         if done:
#    3189             shards_done += 1
#
# File ~/miniconda3/envs/smarthome/lib/python3.9/site-packages/datasets/utils/py_utils.py:654, in iflatmap_unordered(pool, func, kwargs_iterable)
#     651 finally:
#     652     if not pool_changed:
#     653         # we get the result in case there's an error to raise
# --> 654         [async_result.get(timeout=0.05) for async_result in async_results]
#
# File ~/miniconda3/envs/smarthome/lib/python3.9/site-packages/datasets/utils/py_utils.py:654, in <listcomp>(.0)
#     651 finally:
#     652     if not pool_changed:
#     653         # we get the result in case there's an error to raise
# --> 654         [async_result.get(timeout=0.05) for async_result in async_results]
#
# File ~/miniconda3/envs/smarthome/lib/python3.9/site-packages/multiprocess/pool.py:767, in ApplyResult.get(self, timeout)
#     765 self.wait(timeout)
#     766 if not self.ready():
# --> 767     raise TimeoutError
#     768 if self._success:
#     769     return self._value
#
# TimeoutError:

# %%
speech[1000]['audio']['array']

# %%
# Out:
# array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -3.05175781e-05,  0.00000000e+00,  0.00000000e+00])

# %%
preprocess_speech(speech[133]['audio']['array'],model)
# Out:
# tensor([[-0.0040, -0.0037, -0.0029,  ...,  0.0084,  0.0086,  0.0093]])

# %%
base_audio = house[133]['audio']['array']
processed_audio = preprocess_other(house[133]['audio']['array'])

# %%
import IPython

IPython.display.Audio(base_audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython

IPython.display.Audio(processed_audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
